# %%
# !pip install numpy
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib.pyplot
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Final_Data.csv')
df.head()
# Out:
#                          Name  Overall_review      Aircraft Type_of_Traveller  \
# 0                    S Deynal              21   Embraer-190    Couple Leisure
# 1                Branko Stolz               9  Solo Leisure     Economy Class
# 2                    G Maysev              22   A380 / A320          Business
# 3  2 reviews\n\n\n\nR Heirten               9       Embraer          Business
# 4       Gustavo Sirna Barbosa               2  Solo Leisure     Economy Class
#
#           Seat_Type                                    Route  \
# 0     Economy Class            RouteEdinburgh to London City
# 1  London to Vienna                    Date FlownAugust 2023
# 2     Economy Class  RouteSan Francisco to Warsaw via London
# 3     Economy Class            RouteFrankfurt to London City
# 4    London to Lyon                    Date FlownAugust 2023
#
#               Date_Flown
# 0    Date FlownJuly 2023
# 1           Seat Comfort
# 2    Date FlownJuly 2023
# ...

# %%
df.tail()
# Out:
#             Name  Overall_review         Aircraft Type_of_Traveller Seat_Type  \
# 3615    S Luqman              12    Economy Class      Seat Comfort     12345
# 3616     D Smith              13    Economy Class      Seat Comfort     12345
# 3617  Nick Berry              16   Business Class      Seat Comfort     12345
# 3618      C Volz              10  Premium Economy      Seat Comfort     12345
# 3619   Russ King              18      First Class      Seat Comfort     12345
#
#                     Route Date_Flown
# 3615  Cabin Staff Service      12345
# 3616  Cabin Staff Service      12345
# 3617  Cabin Staff Service      12345
# 3618  Cabin Staff Service      12345
# 3619  Cabin Staff Service      12345

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3620 entries, 0 to 3619
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               3620 non-null   object
#  1   Overall_review     3620 non-null   int64
#  2   Aircraft           3620 non-null   object
#  3   Type_of_Traveller  3620 non-null   object
#  4   Seat_Type          3620 non-null   object
#  5   Route              3620 non-null   object
#  6   Date_Flown         3620 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 198.1+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3620, step=1)

# %%
df.shape
# Out:
# (3620, 7)

# %%
df.columns
# Out:
# Index(['Name', 'Overall_review', 'Aircraft', 'Type_of_Traveller', 'Seat_Type',
#        'Route', 'Date_Flown'],
#       dtype='object')

# %%
type(df.columns.tolist())
# Out:
# list

# %%
type(df.index.tolist())
# Out:
# list

# %%
df.describe()
# Out:
#        Overall_review
# count     3620.000000
# mean        15.434530
# std          7.146582
# min          1.000000
# 25%         10.000000
# 50%         15.000000
# 75%         21.000000
# max         35.000000

# %%
sns.distplot(df['Overall_review'])
# Out:
# C:\Users\Muhammad Taha\AppData\Local\Temp\ipykernel_588\2595000504.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Overall_review'])
# <Axes: xlabel='Overall_review', ylabel='Density'>

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x=first_ten, y="Overall_review", data=df[df['Aircraft'].isin(first_ten)], palette="viridis")
plt.xlabel("Type of Aircraft")
plt.ylabel("Overall Review")
plt.title("Distribution of Customer Feedback Ratings for Top 10 Aircraft Types")
plt.xticks(rotation=45)
plt.show()

# %%
first_ten = df['Type_of_Traveller'].head(10)
plt.figure(figsize=(8, 6))
sns.boxplot(x=first_ten, y="Overall_review", data=df[df['Type_of_Traveller'].isin(first_ten)])
plt.title("Box Plot of Overall Review vs Type of Traveller")
plt.xticks(rotation=45)
plt.show()

# %%
first_ten = df['Aircraft'].head(10)
plt.figure(figsize=(8, 6))
sns.pointplot(x="Overall_review", y=first_ten, data=df[df['Aircraft'].isin(first_ten)])
plt.title("Point Plot of Overall Review vs Aircraft")
plt.show()
